# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f"{'Original':<15} | {'Stemmed':<15} | {'Lemmatized':<15}")
print("-" * 50)

for i in range(15):
    word = filtered_tokens[i]
    stemmed = stemmer.stem(word)
    lemma = lemmatizer.lemmatize(word)
    print(f"{word:<15} | {stemmed:<15} | {lemma:<15}")

# %%
# 1. Tokenize
tokens = word_tokenize(raw_text)

# 2. Filter out stop words and punctuation
stop_words = set(stopwords.words('english'))
filtered_tokens = [w for w in tokens if w.isalnum() and w.lower() not in stop_words]

print(f"Original tokens: {len(tokens)}")
print(f"Filtered tokens: {len(filtered_tokens)}")

# %%
# Use the path to your cleaned PyMuPDF output
file_path = "my_output_pymupdf_clean.txt"

if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        raw_text = f.read()
    print(f"Successfully loaded {len(raw_text)} characters.")
else:
    # Fallback text if the file isn't found
    raw_text = "UNITED STATES SECURITIES AND EXCHANGE COMMISSION Washington, D.C. 20549"
    print("Warning: Cleaned file not found. Using sample string.")

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import os

# Download the required data for NLTK
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
